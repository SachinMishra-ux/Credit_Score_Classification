# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./archive/train.csv')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_9196\559357513.py:1: DtypeWarning: Columns (26) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./archive/train.csv')

# %%
df
# Out:
#             ID Customer_ID     Month           Name   Age          SSN  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265
# ...        ...         ...       ...            ...   ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks    25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks    25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks    25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July          Nicks    25  078-73-5990
# 99999  0x25fed  CUS_0x942c    August          Nicks    25  078-73-5990
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# ...

# %%
df.head()
# Out:
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
# 3      19114.12                    NaN                  3  ...        Good
# 4      19114.12            1824.843333                  3  ...        Good
#
# ...

# %%
df.describe()
# Out:
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count           84998.000000      100000.000000     100000.00000
# mean             4194.170850          17.091280         22.47443
# std              3183.686167         117.404834        129.05741
# min               303.645417          -1.000000          0.00000
# 25%              1625.568229           3.000000          4.00000
# 50%              3093.745000           6.000000          5.00000
# 75%              5957.448333           7.000000          7.00000
# max             15204.633333        1798.000000       1499.00000
#
#        Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# count  100000.000000        100000.000000          98035.000000
# mean       72.466040            21.068780             27.754251
# std       466.422621            14.860104            193.177339
# min         1.000000            -5.000000              0.000000
# ...

# %%
df.isnull().sum()
# Out:
# ID                              0
# Customer_ID                     0
# Month                           0
# Name                         9985
# Age                             0
# SSN                             0
# Occupation                      0
# Annual_Income                   0
# Monthly_Inhand_Salary       15002
# Num_Bank_Accounts               0
# Num_Credit_Card                 0
# Interest_Rate                   0
# Num_of_Loan                     0
# Type_of_Loan                11408
# Delay_from_due_date             0
# Num_of_Delayed_Payment       7002
# Changed_Credit_Limit            0
# Num_Credit_Inquiries         1965
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           9030
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4479
# Payment_Behaviour               0
# Monthly_Balance              1200
# ...

# %%
df['Num_Bank_Accounts'].unique()
# Out:
# array([   3,    2,    1,    7,    4,    0,    8,    5,    6,    9,   10,
#        1414, 1231,   67,  572, 1488,   91,  528, 1647, 1696, 1338,  649,
#         889, 1668,  685,  857,  975, 1496, 1534, 1620,   37, 1388, 1429,
#        1332, 1588,  120, 1777, 1096,  803,  494,  744, 1139,  831, 1613,
#         741,  121,  665, 1748, 1644,  823, 1356, 1651,   87,  711,  450,
#         210, 1671, 1722,  648,  672, 1662, 1495,  510,  666,  429, 1131,
#        1434,  980, 1026,  526,  718, 1300, 1312, 1315,  501, 1566,  480,
#        1042,  322,  628, 1016,  333, 1265,  791,  427,  563,  905, 1190,
#        1036, 1611,   38,  619,  555, 1769,  280,  752, 1201,  812, 1487,
#         222,  212, 1019, 1222,  610, 1714, 1308,  525, 1158, 1115, 1616,
#         754, 1601,  797, 1577,  521,  703,  933,  959,  809, 1089, 1656,
#        1113, 1715,  964, 1533, 1789,  871,  434, 1295,  565, 1724,  603,
#         677,  541,  698, 1101,  464, 1539, 1462, 1011, 1257, 1727,   45,
# ...

# %%
df['Num_Credit_Card'].unique()
# Out:
# array([   4, 1385,    5, ...,  955, 1430,  679])

# %%
df['Interest_Rate'].unique()
# Out:
# array([   3,    6,    8, ..., 1347,  387, 5729])

# %%
df['Num_of_Loan'].unique()
# Out:
# array(['4', '1', '3', '967', '-100', '0', '0_', '2', '3_', '2_', '7', '5',
#        '5_', '6', '8', '8_', '9', '9_', '4_', '7_', '1_', '1464', '6_',
#        '622', '352', '472', '1017', '945', '146', '563', '341', '444',
#        '720', '1485', '49', '737', '1106', '466', '728', '313', '843',
#        '597_', '617', '119', '663', '640', '92_', '1019', '501', '1302',
#        '39', '716', '848', '931', '1214', '186', '424', '1001', '1110',
#        '1152', '457', '1433', '1187', '52', '1480', '1047', '1035',
#        '1347_', '33', '193', '699', '329', '1451', '484', '132', '649',
#        '995', '545', '684', '1135', '1094', '1204', '654', '58', '348',
#        '614', '1363', '323', '1406', '1348', '430', '153', '1461', '905',
#        '1312', '1424', '1154', '95', '1353', '1228', '819', '1006', '795',
#        '359', '1209', '590', '696', '1185_', '1465', '911', '1181', '70',
#        '816', '1369', '143', '1416', '455', '55', '1096', '1474', '420',
# ...

# %%
df['Type_of_Loan'].unique()
# Out:
# array(['Auto Loan, Credit-Builder Loan, Personal Loan, and Home Equity Loan',
#        'Credit-Builder Loan', 'Auto Loan, Auto Loan, and Not Specified',
#        ..., 'Home Equity Loan, Auto Loan, Auto Loan, and Auto Loan',
#        'Payday Loan, Student Loan, Mortgage Loan, and Not Specified',
#        'Personal Loan, Auto Loan, Mortgage Loan, Student Loan, and Student Loan'],
#       dtype=object)

# %%
df['Delay_from_due_date'].unique()
# Out:
# array([ 3, -1,  5,  6,  8,  7, 13, 10,  0,  4,  9,  1, 12, 11, 30, 31, 34,
#        27, 14,  2, -2, 16, 17, 15, 23, 22, 21, 18, 19, 52, 51, 48, 53, 26,
#        43, 28, 25, 20, 47, 46, 49, 24, 61, 29, 50, 58, 45, 59, 55, 56, 57,
#        54, 62, 65, 64, 67, 36, 41, 33, 32, 39, 44, 42, 60, 35, 38, -3, 63,
#        40, 37, -5, -4, 66])

# %%
df['Num_of_Delayed_Payment'].unique()
# Out:
# array(['7', nan, '4', '8_', '6', '1', '-1', '3_', '0', '8', '5', '3', '9',
#        '12', '15', '17', '10', '2', '2_', '11', '14', '20', '22', '13',
#        '13_', '14_', '16', '12_', '18', '19', '23', '24', '21', '3318',
#        '3083', '22_', '1338', '4_', '26', '11_', '3104', '21_', '25',
#        '10_', '183_', '9_', '1106', '834', '19_', '24_', '17_', '23_',
#        '2672', '20_', '2008', '-3', '538', '6_', '1_', '16_', '27', '-2',
#        '3478', '2420', '15_', '707', '708', '26_', '18_', '3815', '28',
#        '5_', '1867', '2250', '1463', '25_', '7_', '4126', '2882', '1941',
#        '2655', '2628', '132', '3069', '306', '0_', '3539', '3684', '1823',
#        '4128', '1946', '827', '2297', '2566', '904', '182', '929', '3568',
#        '2503', '1552', '2812', '1697', '3764', '851', '3905', '923', '88',
#        '1668', '3253', '808', '2689', '3858', '642', '3457', '1402',
#        '1732', '3154', '847', '3037', '2204', '3103', '1063', '2056',
# ...

# %%
df['Changed_Credit_Limit'].unique()
# Out:
# array(['11.27', '_', '6.27', ..., '17.509999999999998', '25.16', '21.17'],
#       dtype=object)

# %%
df['Num_Credit_Inquiries'].unique()
# Out:
# array([   4.,    2.,    3., ..., 1361.,  310.,   74.])

# %% [markdown]
# ### Will drop Num_Credit_Card and Num_Bank_Accounts, Interest_Rate, Num of Loans, Num_of_Delayed_Payment,Changed_Credit_Limit, Num_Credit_Inquiries

# %%
df['Credit_Mix'].unique()
# Out:
# array(['_', 'Good', 'Standard', 'Bad'], dtype=object)

# %%
df['Payment_Behaviour'].unique()
# Out:
# array(['High_spent_Small_value_payments',
#        'Low_spent_Large_value_payments',
#        'Low_spent_Medium_value_payments',
#        'Low_spent_Small_value_payments',
#        'High_spent_Medium_value_payments', '!@9#%8',
#        'High_spent_Large_value_payments'], dtype=object)

# %% [markdown]
# ## Seems like no. of bank account will not help much in our model classification so will drop this column.

# %% [markdown]
# ## Will drop ID, Cutomer_ID, Name, Month, SSN, Occupation Columns

# %%
#Drop the column which is out of model scope
d_col = ['ID','Customer_ID','Month','Occupation','Name','SSN','Num_Bank_Accounts','Num_Credit_Card',
         'Interest_Rate','Num_of_Loan','Type_of_Loan','Changed_Credit_Limit','Num_Credit_Inquiries']
drop_df = df.drop(d_col , axis=1).copy()
drop_df
# Out:
#         Age Annual_Income  Monthly_Inhand_Salary  Delay_from_due_date  \
# 0        23      19114.12            1824.843333                    3
# 1        23      19114.12                    NaN                   -1
# 2      -500      19114.12                    NaN                    3
# 3        23      19114.12                    NaN                    5
# 4        23      19114.12            1824.843333                    6
# ...     ...           ...                    ...                  ...
# 99995    25      39628.99            3359.415833                   23
# 99996    25      39628.99            3359.415833                   18
# 99997    25      39628.99            3359.415833                   27
# 99998    25      39628.99            3359.415833                   20
# 99999    25     39628.99_            3359.415833                   18
#
#       Num_of_Delayed_Payment Credit_Mix Outstanding_Debt  \
# 0                          7          _           809.98
# ...

# %%
drop_df.isnull().sum()
# Out:
# Age                             0
# Annual_Income                   0
# Monthly_Inhand_Salary       15002
# Delay_from_due_date             0
# Num_of_Delayed_Payment       7002
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           9030
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4479
# Payment_Behaviour               0
# Monthly_Balance              1200
# Credit_Score                    0
# dtype: int64

# %%
drop_df.dtypes
# Out:
# Age                          object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# Monthly_Balance              object
# Credit_Score                 object
# dtype: object

# %% [markdown]
# ## Let's clean Annual_Income Columns

# %%
drop_df['Annual_Income_new'] = drop_df['Annual_Income'].apply(lambda x: float(x.split('_')[0]))

# %%
drop_df.dtypes
# Out:
# Age                          object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# Monthly_Balance              object
# Credit_Score                 object
# Annual_Income_new           float64
# dtype: object

# %%
# drop_df['Annual_Income'] = drop_df[['Annual_Income']].apply(pd.to_numeric, errors = 'coerce')

# %%
drop_df.isnull().sum()
# Out:
# Age                             0
# Annual_Income                   0
# Monthly_Inhand_Salary       15002
# Delay_from_due_date             0
# Num_of_Delayed_Payment       7002
# Credit_Mix                      0
# Outstanding_Debt                0
# Credit_Utilization_Ratio        0
# Credit_History_Age           9030
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Amount_invested_monthly      4479
# Payment_Behaviour               0
# Monthly_Balance              1200
# Credit_Score                    0
# Annual_Income_new               0
# dtype: int64

# %%
drop_df.head()
# Out:
#     Age Annual_Income  Monthly_Inhand_Salary  Delay_from_due_date  \
# 0    23      19114.12            1824.843333                    3
# 1    23      19114.12                    NaN                   -1
# 2  -500      19114.12                    NaN                    3
# 3    23      19114.12                    NaN                    5
# 4    23      19114.12            1824.843333                    6
#
#   Num_of_Delayed_Payment Credit_Mix Outstanding_Debt  \
# 0                      7          _           809.98
# 1                    NaN       Good           809.98
# 2                      7       Good           809.98
# 3                      4       Good           809.98
# 4                    NaN       Good           809.98
#
#    Credit_Utilization_Ratio     Credit_History_Age Payment_of_Min_Amount  \
# 0                 26.822620  22 Years and 1 Months                    No
# 1                 31.944960                    NaN                    No
# ...

# %% [markdown]
# ## Will fill NA value of Monthly_Inhand_Salary by Annual_Income_new/12 of corresponding row.

# %%
##def Fillnaof_MIsalary(Annual_Income):
   ## return Annual_Income/12

# %%
drop_df.Monthly_Inhand_Salary = np.where(drop_df.Monthly_Inhand_Salary.isnull(), (drop_df.Annual_Income_new)/12, drop_df.Monthly_Inhand_Salary)

# %%
drop_df.isnull().sum()
# Out:
# Age                            0
# Annual_Income                  0
# Monthly_Inhand_Salary          0
# Delay_from_due_date            0
# Num_of_Delayed_Payment      7002
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          9030
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     4479
# Payment_Behaviour              0
# Monthly_Balance             1200
# Credit_Score                   0
# Annual_Income_new              0
# dtype: int64

# %%
drop_df.head()
# Out:
#     Age Annual_Income  Monthly_Inhand_Salary  Delay_from_due_date  \
# 0    23      19114.12            1824.843333                    3
# 1    23      19114.12            1592.843333                   -1
# 2  -500      19114.12            1592.843333                    3
# 3    23      19114.12            1592.843333                    5
# 4    23      19114.12            1824.843333                    6
#
#   Num_of_Delayed_Payment Credit_Mix Outstanding_Debt  \
# 0                      7          _           809.98
# 1                    NaN       Good           809.98
# 2                      7       Good           809.98
# 3                      4       Good           809.98
# 4                    NaN       Good           809.98
#
#    Credit_Utilization_Ratio     Credit_History_Age Payment_of_Min_Amount  \
# 0                 26.822620  22 Years and 1 Months                    No
# 1                 31.944960                    NaN                    No
# ...

# %% [markdown]
# ## Let's clean Age Column

# %%
drop_df['Age_new'] = drop_df['Age'].apply(lambda x: int(x.split('_')[0]))

# %%
drop_df.dtypes
# Out:
# Age                          object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# Monthly_Balance              object
# Credit_Score                 object
# Annual_Income_new           float64
# Age_new                       int64
# dtype: object

# %%
## We will drop those rows where age is less than 18 and greater that 55

# %%
indexAge = drop_df[(drop_df['Age_new'] >= 55) | (drop_df['Age_new'] <= 17) ].index
drop_df.drop(indexAge , inplace=True)
drop_df.head(15)
# Out:
#     Age Annual_Income  Monthly_Inhand_Salary  Delay_from_due_date  \
# 0    23      19114.12            1824.843333                    3
# 1    23      19114.12            1592.843333                   -1
# 3    23      19114.12            1592.843333                    5
# 4    23      19114.12            1824.843333                    6
# 5    23      19114.12            1592.843333                    8
# 6    23      19114.12            1824.843333                    3
# 7    23      19114.12            1824.843333                    3
# 8   28_      34847.84            3037.986667                    3
# 9    28      34847.84            3037.986667                    7
# 10   28     34847.84_            3037.986667                    3
# 11   28      34847.84            2903.986667                    3
# 12   28      34847.84            3037.986667                    3
# 13   28      34847.84            3037.986667                    3
# ...

# %%
drop_df
# Out:
#       Age Annual_Income  Monthly_Inhand_Salary  Delay_from_due_date  \
# 0      23      19114.12            1824.843333                    3
# 1      23      19114.12            1592.843333                   -1
# 3      23      19114.12            1592.843333                    5
# 4      23      19114.12            1824.843333                    6
# 5      23      19114.12            1592.843333                    8
# ...    ..           ...                    ...                  ...
# 99995  25      39628.99            3359.415833                   23
# 99996  25      39628.99            3359.415833                   18
# 99997  25      39628.99            3359.415833                   27
# 99998  25      39628.99            3359.415833                   20
# 99999  25     39628.99_            3359.415833                   18
#
#       Num_of_Delayed_Payment Credit_Mix Outstanding_Debt  \
# 0                          7          _           809.98
# ...

# %%
drop_df.isnull().sum()
# Out:
# Age                            0
# Annual_Income                  0
# Monthly_Inhand_Salary          0
# Delay_from_due_date            0
# Num_of_Delayed_Payment      6325
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Credit_History_Age          8142
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Amount_invested_monthly     4012
# Payment_Behaviour              0
# Monthly_Balance             1070
# Credit_Score                   0
# Annual_Income_new              0
# Age_new                        0
# dtype: int64

# %%
drop_df.dtypes
# Out:
# Age                          object
# Annual_Income                object
# Monthly_Inhand_Salary       float64
# Delay_from_due_date           int64
# Num_of_Delayed_Payment       object
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Credit_History_Age           object
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Amount_invested_monthly      object
# Payment_Behaviour            object
# Monthly_Balance              object
# Credit_Score                 object
# Annual_Income_new           float64
# Age_new                       int64
# dtype: object

# %% [markdown]
# ## looks like Credit_History_Age column is not relevant since years are greater than age , so will drop it.
# ## Similirly Num_of_Delayed_Payment is also not relevant, will drop it
# ## Amount_invested_monthly will not have any relation with Credit_Score will drop it.

# %%
d_col1 = ['Num_of_Delayed_Payment','Credit_History_Age','Amount_invested_monthly','Age','Annual_Income']
df_new = drop_df.drop(d_col1 , axis=1).copy()
df_new
# Out:
#        Monthly_Inhand_Salary  Delay_from_due_date Credit_Mix Outstanding_Debt  \
# 0                1824.843333                    3          _           809.98
# 1                1592.843333                   -1       Good           809.98
# 3                1592.843333                    5       Good           809.98
# 4                1824.843333                    6       Good           809.98
# 5                1592.843333                    8       Good           809.98
# ...                      ...                  ...        ...              ...
# 99995            3359.415833                   23          _           502.38
# 99996            3359.415833                   18          _           502.38
# 99997            3359.415833                   27       Good           502.38
# 99998            3359.415833                   20       Good           502.38
# 99999            3359.415833                   18       Good           502.38
#
# ...

# %%
df_new.isnull().sum()
# Out:
# Monthly_Inhand_Salary          0
# Delay_from_due_date            0
# Credit_Mix                     0
# Outstanding_Debt               0
# Credit_Utilization_Ratio       0
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Payment_Behaviour              0
# Monthly_Balance             1070
# Credit_Score                   0
# Annual_Income_new              0
# Age_new                        0
# dtype: int64

# %%
df_new1 = df_new.dropna()

# %%
df_new1
# Out:
#        Monthly_Inhand_Salary  Delay_from_due_date Credit_Mix Outstanding_Debt  \
# 0                1824.843333                    3          _           809.98
# 1                1592.843333                   -1       Good           809.98
# 3                1592.843333                    5       Good           809.98
# 4                1824.843333                    6       Good           809.98
# 5                1592.843333                    8       Good           809.98
# ...                      ...                  ...        ...              ...
# 99995            3359.415833                   23          _           502.38
# 99996            3359.415833                   18          _           502.38
# 99997            3359.415833                   27       Good           502.38
# 99998            3359.415833                   20       Good           502.38
# 99999            3359.415833                   18       Good           502.38
#
# ...

# %%
df_new1.isnull().sum()
# Out:
# Monthly_Inhand_Salary       0
# Delay_from_due_date         0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# Annual_Income_new           0
# Age_new                     0
# dtype: int64

# %%
df_new1.dtypes
# Out:
# Monthly_Inhand_Salary       float64
# Delay_from_due_date           int64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Payment_Behaviour            object
# Monthly_Balance              object
# Credit_Score                 object
# Annual_Income_new           float64
# Age_new                       int64
# dtype: object

# %% [markdown]
# ## Again let's check some unique values

# %%
df_new1['Delay_from_due_date'].unique()
# Out:
# array([ 3, -1,  5,  6,  8,  7, 13, 10,  0,  9,  1, 12, 11, 30, 31, 34, 27,
#        14,  4,  2, -2, 16, 17, 15, 23, 22, 21, 18, 19, 52, 51, 48, 53, 26,
#        43, 28, 25, 20, 47, 49, 24, 61, 29, 45, 59, 55, 56, 62, 65, 64, 54,
#        67, 50, 36, 41, 57, 39, 44, 46, 33, 35, 38, -3, 60, 63, 42, 40, 32,
#        37, -5, 58, -4, 66])

# %%
df_new1['Outstanding_Debt'].unique()
# Out:
# array(['809.98', '605.03', '1303.01', ..., '3571.7_', '3571.7', '502.38'],
#       dtype=object)

# %% [markdown]
# ## Let's deal with Outstanding_Debt column ; same _ pattern is there.

# %%
df_new1['Outstanding_Debt_new'] = df_new1['Outstanding_Debt'].apply(lambda x: float(x.split('_')[0]))
# Out:
# /var/folders/88/hhxvgfgx35j6b78wj1brvz2m0000gr/T/ipykernel_14993/2759201543.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new1['Outstanding_Debt_new'] = df_new1['Outstanding_Debt'].apply(lambda x: float(x.split('_')[0]))

# %%
df_new1
# Out:
#        Monthly_Inhand_Salary  Delay_from_due_date Credit_Mix Outstanding_Debt  \
# 0                1824.843333                    3          _           809.98
# 1                1592.843333                   -1       Good           809.98
# 3                1592.843333                    5       Good           809.98
# 4                1824.843333                    6       Good           809.98
# 5                1592.843333                    8       Good           809.98
# ...                      ...                  ...        ...              ...
# 99995            3359.415833                   23          _           502.38
# 99996            3359.415833                   18          _           502.38
# 99997            3359.415833                   27       Good           502.38
# 99998            3359.415833                   20       Good           502.38
# 99999            3359.415833                   18       Good           502.38
#
# ...

# %%
df_new1.dtypes
# Out:
# Monthly_Inhand_Salary       float64
# Delay_from_due_date           int64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Payment_Behaviour            object
# Monthly_Balance              object
# Credit_Score                 object
# Annual_Income_new           float64
# Age_new                       int64
# Outstanding_Debt_new        float64
# dtype: object

# %%
df_new1['Monthly_Balance'].unique()
# Out:
# array(['312.49408867943663', '284.62916249607184', '223.45130972736786',
#        ..., 516.8090832742814, 319.1649785257098, 393.6736955618808],
#       dtype=object)

# %%
def Monthly_Balance_Convertor(x):
    try:
        return float(x)
    except:
        return None

# %%
df_new1['Monthly_Balance_new'] = df_new1['Monthly_Balance'].apply(Monthly_Balance_Convertor)
# Out:
# /var/folders/88/hhxvgfgx35j6b78wj1brvz2m0000gr/T/ipykernel_14993/363711963.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_new1['Monthly_Balance_new'] = df_new1['Monthly_Balance'].apply(Monthly_Balance_Convertor)

# %%
df_new1
# Out:
#        Monthly_Inhand_Salary  Delay_from_due_date Credit_Mix Outstanding_Debt  \
# 0                1824.843333                    3          _           809.98
# 1                1592.843333                   -1       Good           809.98
# 3                1592.843333                    5       Good           809.98
# 4                1824.843333                    6       Good           809.98
# 5                1592.843333                    8       Good           809.98
# ...                      ...                  ...        ...              ...
# 99995            3359.415833                   23          _           502.38
# 99996            3359.415833                   18          _           502.38
# 99997            3359.415833                   27       Good           502.38
# 99998            3359.415833                   20       Good           502.38
# 99999            3359.415833                   18       Good           502.38
#
# ...

# %%
df_new1.dtypes
# Out:
# Monthly_Inhand_Salary       float64
# Delay_from_due_date           int64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Payment_Behaviour            object
# Monthly_Balance              object
# Credit_Score                 object
# Annual_Income_new           float64
# Age_new                       int64
# Outstanding_Debt_new        float64
# Monthly_Balance_new         float64
# dtype: object

# %%
df_new1.isnull().sum()
# Out:
# Monthly_Inhand_Salary       0
# Delay_from_due_date         0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# Annual_Income_new           0
# Age_new                     0
# Outstanding_Debt_new        0
# Monthly_Balance_new         7
# dtype: int64

# %%
df_new2 = df_new1.dropna()

# %%
df_new2
# Out:
#        Monthly_Inhand_Salary  Delay_from_due_date Credit_Mix Outstanding_Debt  \
# 0                1824.843333                    3          _           809.98
# 1                1592.843333                   -1       Good           809.98
# 3                1592.843333                    5       Good           809.98
# 4                1824.843333                    6       Good           809.98
# 5                1592.843333                    8       Good           809.98
# ...                      ...                  ...        ...              ...
# 99995            3359.415833                   23          _           502.38
# 99996            3359.415833                   18          _           502.38
# 99997            3359.415833                   27       Good           502.38
# 99998            3359.415833                   20       Good           502.38
# 99999            3359.415833                   18       Good           502.38
#
# ...

# %%
df_new2.isnull().sum()
# Out:
# Monthly_Inhand_Salary       0
# Delay_from_due_date         0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_Utilization_Ratio    0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Payment_Behaviour           0
# Monthly_Balance             0
# Credit_Score                0
# Annual_Income_new           0
# Age_new                     0
# Outstanding_Debt_new        0
# Monthly_Balance_new         0
# dtype: int64

# %%
df_new2.dtypes
# Out:
# Monthly_Inhand_Salary       float64
# Delay_from_due_date           int64
# Credit_Mix                   object
# Outstanding_Debt             object
# Credit_Utilization_Ratio    float64
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Payment_Behaviour            object
# Monthly_Balance              object
# Credit_Score                 object
# Annual_Income_new           float64
# Age_new                       int64
# Outstanding_Debt_new        float64
# Monthly_Balance_new         float64
# dtype: object

# %% [markdown]
# ## Let's work on outliers

# %%
import seaborn as sns
sns.boxplot(df_new2['Outstanding_Debt_new'])
# Out:
# /Users/sachinmishra/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Outstanding_Debt_new'>

# %% [markdown]
# ## Ok we need these outliers,so we won't remove them

# %% [markdown]
# ## Okay let's drop Outstanding_Debt & Monthly_Balance

# %%
d_col2 = ['Outstanding_Debt','Monthly_Balance']
df_new3 = df_new2.drop(d_col2 , axis=1).copy()
df_new3
# Out:
#        Monthly_Inhand_Salary  Delay_from_due_date Credit_Mix  \
# 0                1824.843333                    3          _
# 1                1592.843333                   -1       Good
# 3                1592.843333                    5       Good
# 4                1824.843333                    6       Good
# 5                1592.843333                    8       Good
# ...                      ...                  ...        ...
# 99995            3359.415833                   23          _
# 99996            3359.415833                   18          _
# 99997            3359.415833                   27       Good
# 99998            3359.415833                   20       Good
# 99999            3359.415833                   18       Good
#
#        Credit_Utilization_Ratio Payment_of_Min_Amount  Total_EMI_per_month  \
# 0                     26.822620                    No            49.574949
# 1                     31.944960                    No            49.574949
# ...

# %% [markdown]
# ## Now, let's deal with 'Credit_Mix' column

# %% [markdown]
# ## Will replace - values with nearby value of column

# %%
df_new3['Credit_Mix_new'] = np.where((df_new3['Credit_Mix'] == '_'), None ,df_new3['Credit_Mix'])

# %%
df_new3
# Out:
#        Monthly_Inhand_Salary  Delay_from_due_date Credit_Mix  \
# 0                1824.843333                    3          _
# 1                1592.843333                   -1       Good
# 3                1592.843333                    5       Good
# 4                1824.843333                    6       Good
# 5                1592.843333                    8       Good
# ...                      ...                  ...        ...
# 99995            3359.415833                   23          _
# 99996            3359.415833                   18          _
# 99997            3359.415833                   27       Good
# 99998            3359.415833                   20       Good
# 99999            3359.415833                   18       Good
#
#        Credit_Utilization_Ratio Payment_of_Min_Amount  Total_EMI_per_month  \
# 0                     26.822620                    No            49.574949
# 1                     31.944960                    No            49.574949
# ...

# %%
df_new3.isnull().sum()
# Out:
# Monthly_Inhand_Salary           0
# Delay_from_due_date             0
# Credit_Mix                      0
# Credit_Utilization_Ratio        0
# Payment_of_Min_Amount           0
# Total_EMI_per_month             0
# Payment_Behaviour               0
# Credit_Score                    0
# Annual_Income_new               0
# Age_new                         0
# Outstanding_Debt_new            0
# Monthly_Balance_new             0
# Credit_Mix_new              17947
# dtype: int64

# %%
df_new3.bfill(axis ='rows',inplace=True)

# %%
df_new3
# Out:
#        Monthly_Inhand_Salary  Delay_from_due_date Credit_Mix  \
# 0                1824.843333                    3          _
# 1                1592.843333                   -1       Good
# 3                1592.843333                    5       Good
# 4                1824.843333                    6       Good
# 5                1592.843333                    8       Good
# ...                      ...                  ...        ...
# 99995            3359.415833                   23          _
# 99996            3359.415833                   18          _
# 99997            3359.415833                   27       Good
# 99998            3359.415833                   20       Good
# 99999            3359.415833                   18       Good
#
#        Credit_Utilization_Ratio Payment_of_Min_Amount  Total_EMI_per_month  \
# 0                     26.822620                    No            49.574949
# 1                     31.944960                    No            49.574949
# ...

# %%
df_new3.isnull().sum()
# Out:
# Monthly_Inhand_Salary       0
# Delay_from_due_date         0
# Credit_Mix                  0
# Credit_Utilization_Ratio    0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Payment_Behaviour           0
# Credit_Score                0
# Annual_Income_new           0
# Age_new                     0
# Outstanding_Debt_new        0
# Monthly_Balance_new         0
# Credit_Mix_new              0
# dtype: int64

# %% [markdown]
# ## Now let's deal with Payment_Behaviour column

# %%
df_new3['Payment_Behaviour_new'] = np.where((df_new3['Payment_Behaviour'] == '!@9#%8'), None ,df_new3['Payment_Behaviour'])

# %%
df_new3.isnull().sum()
# Out:
# Monthly_Inhand_Salary          0
# Delay_from_due_date            0
# Credit_Mix                     0
# Credit_Utilization_Ratio       0
# Payment_of_Min_Amount          0
# Total_EMI_per_month            0
# Payment_Behaviour              0
# Credit_Score                   0
# Annual_Income_new              0
# Age_new                        0
# Outstanding_Debt_new           0
# Monthly_Balance_new            0
# Credit_Mix_new                 0
# Payment_Behaviour_new       6719
# dtype: int64

# %%
df_new3.ffill(axis ='rows',inplace=True)

# %%
df_new3.isnull().sum()
# Out:
# Monthly_Inhand_Salary       0
# Delay_from_due_date         0
# Credit_Mix                  0
# Credit_Utilization_Ratio    0
# Payment_of_Min_Amount       0
# Total_EMI_per_month         0
# Payment_Behaviour           0
# Credit_Score                0
# Annual_Income_new           0
# Age_new                     0
# Outstanding_Debt_new        0
# Monthly_Balance_new         0
# Credit_Mix_new              0
# Payment_Behaviour_new       0
# dtype: int64

# %%
df_new3
# Out:
#        Monthly_Inhand_Salary  Delay_from_due_date Credit_Mix  \
# 0                1824.843333                    3          _
# 1                1592.843333                   -1       Good
# 3                1592.843333                    5       Good
# 4                1824.843333                    6       Good
# 5                1592.843333                    8       Good
# ...                      ...                  ...        ...
# 99995            3359.415833                   23          _
# 99996            3359.415833                   18          _
# 99997            3359.415833                   27       Good
# 99998            3359.415833                   20       Good
# 99999            3359.415833                   18       Good
#
#        Credit_Utilization_Ratio Payment_of_Min_Amount  Total_EMI_per_month  \
# 0                     26.822620                    No            49.574949
# 1                     31.944960                    No            49.574949
# ...

# %%
d_col3 = ['Credit_Mix','Payment_Behaviour']
cleaned_df = df_new3.drop(d_col3 , axis=1).copy()
cleaned_df
# Out:
#        Monthly_Inhand_Salary  Delay_from_due_date  Credit_Utilization_Ratio  \
# 0                1824.843333                    3                 26.822620
# 1                1592.843333                   -1                 31.944960
# 3                1592.843333                    5                 31.377862
# 4                1824.843333                    6                 24.797347
# 5                1592.843333                    8                 27.262259
# ...                      ...                  ...                       ...
# 99995            3359.415833                   23                 34.663572
# 99996            3359.415833                   18                 40.565631
# 99997            3359.415833                   27                 41.255522
# 99998            3359.415833                   20                 33.638208
# 99999            3359.415833                   18                 34.192463
#
# ...

# %%
cleaned_df.dtypes
# Out:
# Monthly_Inhand_Salary       float64
# Delay_from_due_date           int64
# Credit_Utilization_Ratio    float64
# Payment_of_Min_Amount        object
# Total_EMI_per_month         float64
# Credit_Score                 object
# Annual_Income_new           float64
# Age_new                       int64
# Outstanding_Debt_new        float64
# Monthly_Balance_new         float64
# Credit_Mix_new               object
# Payment_Behaviour_new        object
# dtype: object

# %%
cleaned_df.to_csv('cleaned_file.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 cleaned_df.to_csv('cleaned_file.csv')
#
# NameError: name 'cleaned_df' is not defined

# %%
df1 = pd.read_csv('./archive/cleaned_file.csv')

# %%
df1
# Out:
#        Monthly_Inhand_Salary  Delay_from_due_date  Credit_Utilization_Ratio  \
# 0                1824.843333                    3                 26.822620
# 1                1592.843333                   -1                 31.944960
# 2                1592.843333                    5                 31.377862
# 3                1824.843333                    6                 24.797347
# 4                1592.843333                    8                 27.262259
# ...                      ...                  ...                       ...
# 88703            3359.415833                   23                 34.663572
# 88704            3359.415833                   18                 40.565631
# 88705            3359.415833                   27                 41.255522
# 88706            3359.415833                   20                 33.638208
# 88707            3359.415833                   18                 34.192463
#
# ...

# %%
df1['Payment_of_Min_Amount'].unique()
# Out:
# array(['No', 'NM', 'Yes'], dtype=object)

# %% [markdown]
# ## Let's deal with Payment_of_Min_Amount Column, where NM is present we will replace it with No

# %%
df1['Payment_of_Min_Amount_new'] = np.where((df1['Payment_of_Min_Amount'] == 'NM'), 'No' ,df1['Payment_of_Min_Amount'])

# %%
df1
# Out:
#        Monthly_Inhand_Salary  Delay_from_due_date  Credit_Utilization_Ratio  \
# 0                1824.843333                    3                 26.822620
# 1                1592.843333                   -1                 31.944960
# 2                1592.843333                    5                 31.377862
# 3                1824.843333                    6                 24.797347
# 4                1592.843333                    8                 27.262259
# ...                      ...                  ...                       ...
# 88703            3359.415833                   23                 34.663572
# 88704            3359.415833                   18                 40.565631
# 88705            3359.415833                   27                 41.255522
# 88706            3359.415833                   20                 33.638208
# 88707            3359.415833                   18                 34.192463
#
# ...

# %%
# Remove column name 'A'
df1.drop(['Payment_of_Min_Amount'], axis=1,inplace=True)

# %%
df1
# Out:
#        Monthly_Inhand_Salary  Delay_from_due_date  Credit_Utilization_Ratio  \
# 0                1824.843333                    3                 26.822620
# 1                1592.843333                   -1                 31.944960
# 2                1592.843333                    5                 31.377862
# 3                1824.843333                    6                 24.797347
# 4                1592.843333                    8                 27.262259
# ...                      ...                  ...                       ...
# 88703            3359.415833                   23                 34.663572
# 88704            3359.415833                   18                 40.565631
# 88705            3359.415833                   27                 41.255522
# 88706            3359.415833                   20                 33.638208
# 88707            3359.415833                   18                 34.192463
#
# ...

# %% [markdown]
# ## Will Use One hot Encoding to deal with Categorical Variables

# %%
# Multiple categorical columns
categorical_cols = ['Credit_Mix_new', 'Payment_Behaviour_new', 'Payment_of_Min_Amount_new']

df2= pd.get_dummies(df1, columns=categorical_cols)

# %%
df2
# Out:
#        Monthly_Inhand_Salary  Delay_from_due_date  Credit_Utilization_Ratio  \
# 0                1824.843333                    3                 26.822620
# 1                1592.843333                   -1                 31.944960
# 2                1592.843333                    5                 31.377862
# 3                1824.843333                    6                 24.797347
# 4                1592.843333                    8                 27.262259
# ...                      ...                  ...                       ...
# 88703            3359.415833                   23                 34.663572
# 88704            3359.415833                   18                 40.565631
# 88705            3359.415833                   27                 41.255522
# 88706            3359.415833                   20                 33.638208
# 88707            3359.415833                   18                 34.192463
#
# ...

# %%
df2['Credit_Score'].unique()
# Out:
# array(['Good', 'Standard', 'Poor'], dtype=object)

# %%
def EncodeTarget(x):
    if x=='Good':
        return int(1)
    elif x=='Standard':
        return int(2)
    else:
        return int(3)

# %%
df2['Credit_Score_new'] = df2['Credit_Score'].apply(EncodeTarget)

# %%
df2
# Out:
#        Monthly_Inhand_Salary  Delay_from_due_date  Credit_Utilization_Ratio  \
# 0                1824.843333                    3                 26.822620
# 1                1592.843333                   -1                 31.944960
# 2                1592.843333                    5                 31.377862
# 3                1824.843333                    6                 24.797347
# 4                1592.843333                    8                 27.262259
# ...                      ...                  ...                       ...
# 88703            3359.415833                   23                 34.663572
# 88704            3359.415833                   18                 40.565631
# 88705            3359.415833                   27                 41.255522
# 88706            3359.415833                   20                 33.638208
# 88707            3359.415833                   18                 34.192463
#
# ...

# %%
# Remove column name 'A'
df2.drop(['Credit_Score'], axis=1,inplace=True)

# %%
df2.dtypes
# Out:
# Monthly_Inhand_Salary                                     float64
# Delay_from_due_date                                         int64
# Credit_Utilization_Ratio                                  float64
# Total_EMI_per_month                                       float64
# Annual_Income_new                                         float64
# Age_new                                                     int64
# Outstanding_Debt_new                                      float64
# Monthly_Balance_new                                       float64
# Credit_Mix_new_Bad                                          uint8
# Credit_Mix_new_Good                                         uint8
# Credit_Mix_new_Standard                                     uint8
# Payment_Behaviour_new_High_spent_Large_value_payments       uint8
# Payment_Behaviour_new_High_spent_Medium_value_payments      uint8
# Payment_Behaviour_new_High_spent_Small_value_payments       uint8
# ...

# %%
## Input
inputs_n = df2.drop(['Credit_Score_new'],axis='columns')

# %%
inputs_n
# Out:
#        Monthly_Inhand_Salary  Delay_from_due_date  Credit_Utilization_Ratio  \
# 0                1824.843333                    3                 26.822620
# 1                1592.843333                   -1                 31.944960
# 2                1592.843333                    5                 31.377862
# 3                1824.843333                    6                 24.797347
# 4                1592.843333                    8                 27.262259
# ...                      ...                  ...                       ...
# 88703            3359.415833                   23                 34.663572
# 88704            3359.415833                   18                 40.565631
# 88705            3359.415833                   27                 41.255522
# 88706            3359.415833                   20                 33.638208
# 88707            3359.415833                   18                 34.192463
#
# ...

# %%
## Target Column
target = df2['Credit_Score_new']

# %%
target
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 88703    3
# 88704    3
# 88705    3
# 88706    2
# 88707    3
# Name: Credit_Score_new, Length: 88708, dtype: int64

# %% [markdown]
# ## Let's Use randomized search CV

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn import tree

model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto'),
        'params' : {
            'C': [1,10,20],
            'kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'C': [1,5,10]
        }
    },
    'decision_tree':{
        'model':tree.DecisionTreeClassifier(),
        'params':{
            'criterion': ['gini', 'entropy', 'log_loss']
        }
    }
}

# %%
scores = []
from sklearn.model_selection import GridSearchCV
for model_name, mp in model_params.items():
    clf =  GridSearchCV(mp['model'], mp['params'], cv=5, return_train_score=False)
    clf.fit(inputs_n, target)
    scores.append({
        'model': model_name,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(inputs_n,target,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=35)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=35)

# %%
model.score(X_test, y_test)
# Out:
# 0.7510990869124112

# %%
y_predicted = model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predicted)
cm
# Out:
# array([[2304,  845,   48],
#        [ 944, 7341, 1185],
#        [ 237, 1157, 3681]])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sn
plt.figure(figsize=(10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
import pickle
with open('model_pickle','wb') as file:
    pickle.dump(model,file)

# %%
model.predict([[1824.843333,3,26.822620,49.574949,19114.12,23,809.98,312.494089,0,1,0,0,0,1,0,0,0,1,0]])[0]
# Out:
# /Users/sachinmishra/opt/anaconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# 1

# %%
import json
columns = {
    'data_columns' : [col.lower() for col in inputs_n.columns]
}
with open("columns.json","w") as f:
    f.write(json.dumps(columns))
